# %%
# !pip install scikit-learn
# !pip install pandas
# !pip install emoji
# !pip install num2words
# !pip install nltk
# !pip install matplotlib
# !pip install wordcloud
# !pip install ipynb 
# !pip install seaborn
# !pip install python-docx
# Out:
# Requirement already satisfied: scikit-learn in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pandas in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: emoji in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (2.12.1)
# Requirement already satisfied: typing-extensions>=4.7.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from emoji) (4.12.2)
# Requirement already satisfied: num2words in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (0.5.13)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from num2words) (0.6.2)
# Requirement already satisfied: nltk in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: matplotlib in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: wordcloud in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from wordcloud) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: ipynb in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (0.5.1)
# Requirement already satisfied: seaborn in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: python-docx in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-docx) (5.2.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-docx) (4.12.2)

# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split
import re
import emoji
from num2words import num2words
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
nltk.download('stopwords')
nltk.download('wordnet')
import matplotlib.pyplot as plt
from collections import defaultdict
from collections import Counter
from matplotlib import colors
import pandas as pd
from ipynb.fs.full.preprocessor_class import Preprocessor
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
import seaborn as sns
from sklearn.metrics import confusion_matrix
import docx
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tiast\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\tiast\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
train_data = pd.read_csv('data/shuffled_train_data.csv',index_col=None)
train_labels = pd.read_csv('data/shuffled_train_labels.csv',index_col=None)

test_data = pd.read_csv('data/test_data.csv',index_col=None)
test_labels = pd.read_csv('data/test_labels.csv',index_col=None)

train_data_plot = pd.read_csv('data/train_data_plot.csv',index_col=None)
test_data_plot = pd.read_csv('data/test_data_plot.csv',index_col=None)

train_data.shape
# Out:
# (2100, 1)

# %%
preprocessor = Preprocessor(set(stopwords.words('romanian')),None, None, True, True, True, True, False, True, True, True, True, False, False)

preprocessed_data = pd.DataFrame(columns=['text'])

preprocessed_train_data = pd.DataFrame(columns=['text'])
preprocessed_test_data = pd.DataFrame(columns=['text'])

preprocessed_train_data['text'] = train_data.apply(lambda row: preprocessor.preprocess(row.iloc[0]), axis = 1)
preprocessed_test_data['text'] = test_data.apply(lambda row: preprocessor.preprocess(row.iloc[0]), axis = 1)

# %%
preprocessed_test_data['text'] = preprocessed_test_data['text'].apply(lambda x: ' '.join(map(str, x)))
preprocessed_test_data
# Out:
#                                                    text
# 0     mare durere fizica simtita clasa ten stomatolo...
# 1     petitie asf impotriva speculei asiguratorilor ...
# 2     ride sharing plecat proteste redditori masini ...
# 3     apasa trimite refugiat sprit ten salvati gold ...
# 4     politia datoria scurt depus plangere politie m...
# ...                                                 ...
# 1320  sfat buna neboie sfat facut doza vaccin contra...
# 1321  boli mintale soferii tir dn1 locuit an jumatat...
# 1322  freelancer gasesc clienti gasesc client job fr...
# 1323  furata cunostinta spune probe suficiente furat...
# 1324  merita aprofundezi js frontend devs merita inv...
#
# [1325 rows x 1 columns]

# %%
preprocessed_train_data['text'] = preprocessed_train_data['text'].apply(lambda x: ' '.join(map(str, x)))
preprocessed_train_data
# Out:
#                                                    text
# 0     rant ajuns cumparam originalul postare tip imp...
# 1     true grit secretul succesului evident ideile c...
# 2     experiente schimbat mentalitatea buna experien...
# 3     subreddit trebui numeasca r depresie casual ti...
# 4     ticalosilor entr acte unchiul scrie decat marc...
# ...                                                 ...
# 2095  mersul sala eticheta mno inceput merg sala tov...
# 2096  maine sala controla emotiile long story short ...
# 2097  stie gasesc granita italiana intors sicilia ma...
# 2098  somn permanenta stiu fac efectiv somn momentul...
# 2099  rodditori programatori oameni buni rog salvati...
#
# [2100 rows x 1 columns]

# %%
best_f1 = 0
chosen_parameters = {}
data = []

for vocab in [1000, 3000, 5000]:
  for ij in range(1, 4):
    for kernel in ['linear', 'poly', 'rbf', 'sigmoid']:
      for gamma in ['scale', 'auto']:
        for c in [1, 100, 1000]:
            #initiate the TfidfVectorizer
            
            tfidf_vectorizer = TfidfVectorizer(max_features = vocab, ngram_range = (1,ij))
            train_tfidf = tfidf_vectorizer.fit_transform(preprocessed_train_data['text']) 
            test_tfidf = tfidf_vectorizer.transform(preprocessed_test_data['text']) 
            
            model = SVC(C = c, kernel = kernel, gamma = gamma)
            
            model.fit(train_tfidf, train_labels['label'])
            predictions = model.predict(test_tfidf)
            f1 = metrics.f1_score(test_labels['label'], predictions, average = 'macro')
    
            print('max_features: {} n_gram: {}  kernel: {}  gamma: {}  C: {}  f1: {}'.format(vocab, (1, ij), kernel, gamma, c, f1))
            data.append({
              "max_features": vocab,
              "n_gram": (1, ij),
              "kernel": kernel,
              "gamma": gamma,
              "C": c,
              "f1": f1
            })
            
            if f1 > best_f1:
                best_f1 = f1
                chosen_parameters["max_features"] = vocab
                chosen_parameters["n_gram"] = (1, ij)        
                chosen_parameters["kernel"] = kernel
                chosen_parameters["gamma"] = gamma
                chosen_parameters["C"] = c

print(best_f1)
print(chosen_parameters)
# Out:
# max_features: 1000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 1  f1: 0.3485356494646152
# max_features: 1000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 100  f1: 0.39813260479643214
# max_features: 1000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 1000  f1: 0.3911057787331276
# max_features: 1000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 1  f1: 0.3485356494646152
# max_features: 1000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 100  f1: 0.39813260479643214
# max_features: 1000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 1000  f1: 0.3911057787331276
# max_features: 1000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 1  f1: 0.31090505186266165
# max_features: 1000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 100  f1: 0.3156825662180636
# max_features: 1000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 1000  f1: 0.3156825662180636
# max_features: 1000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 1  f1: 0.3188989124479713
# max_features: 1000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 100  f1: 0.38213734904779956
# max_features: 1000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 1000  f1: 0.37842561830933924
# max_features: 1000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 1000  f1: 0.3934732510886396
# max_features: 1000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.34976328207663016
# max_features: 1000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.40999748728821933
# max_features: 1000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.4043994956125161
# max_features: 1000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.3485356494646152
# max_features: 1000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 1  f1: 0.3593503998016488
# max_features: 1000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 100  f1: 0.3877719403775007
# max_features: 1000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 1000  f1: 0.39560006455503743
# max_features: 1000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 1  f1: 0.3593503998016488
# max_features: 1000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 100  f1: 0.3877719403775007
# max_features: 1000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 1000  f1: 0.39560006455503743
# max_features: 1000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 1  f1: 0.31090505186266165
# max_features: 1000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 100  f1: 0.31801370533749224
# max_features: 1000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 1000  f1: 0.31801370533749224
# max_features: 1000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 1  f1: 0.31875155788199266
# max_features: 1000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 100  f1: 0.39307596501694486
# max_features: 1000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 1000  f1: 0.3907949570423365
# max_features: 1000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 1000  f1: 0.39487692949520237
# max_features: 1000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.3424469082192824
# max_features: 1000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.3968520023013937
# max_features: 1000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.40186916853009086
# max_features: 1000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.3593503998016488
# max_features: 1000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 1  f1: 0.3541013683323966
# max_features: 1000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 100  f1: 0.38895220476906217
# max_features: 1000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 1000  f1: 0.3855604563151733
# max_features: 1000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 1  f1: 0.3541013683323966
# max_features: 1000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 100  f1: 0.38895220476906217
# max_features: 1000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 1000  f1: 0.3855604563151733
# max_features: 1000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 1  f1: 0.31090505186266165
# max_features: 1000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 100  f1: 0.31801370533749224
# max_features: 1000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 1000  f1: 0.31801370533749224
# max_features: 1000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 1  f1: 0.31862547358596527
# max_features: 1000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 100  f1: 0.39670218195358814
# max_features: 1000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 1000  f1: 0.39443257023734696
# max_features: 1000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 1000  f1: 0.3903205046238254
# max_features: 1000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.3407009211209357
# max_features: 1000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.41096241809326317
# max_features: 1000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.4009009856756545
# max_features: 1000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 1000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.3541013683323966
# max_features: 3000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 1  f1: 0.36899690260199813
# max_features: 3000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 100  f1: 0.401853079381914
# max_features: 3000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 1000  f1: 0.4009226147680685
# max_features: 3000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 1  f1: 0.36899690260199813
# max_features: 3000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 100  f1: 0.401853079381914
# max_features: 3000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 1000  f1: 0.4009226147680685
# max_features: 3000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 1  f1: 0.3036127426516693
# max_features: 3000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 100  f1: 0.3084437795288409
# max_features: 3000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 1000  f1: 0.3084437795288409
# max_features: 3000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 1  f1: 0.32129659303572344
# max_features: 3000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 100  f1: 0.3706899346010255
# max_features: 3000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 1000  f1: 0.37318969171300775
# max_features: 3000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 1000  f1: 0.33066428731449937
# max_features: 3000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.3476861426326853
# max_features: 3000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.3971829248936611
# max_features: 3000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.3854951952571315
# max_features: 3000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.2869852202611565
# max_features: 3000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 1  f1: 0.3536278245828696
# max_features: 3000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 100  f1: 0.42394401857327707
# max_features: 3000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 1000  f1: 0.4211910858496694
# max_features: 3000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 1  f1: 0.3536278245828696
# max_features: 3000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 100  f1: 0.42394401857327707
# max_features: 3000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 1000  f1: 0.4211910858496694
# max_features: 3000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 1  f1: 0.3060362142236048
# max_features: 3000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 100  f1: 0.3084437795288409
# max_features: 3000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 1000  f1: 0.3060362142236048
# max_features: 3000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 1  f1: 0.3235597512107579
# max_features: 3000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 100  f1: 0.36842888729416784
# max_features: 3000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 1000  f1: 0.37518425058078986
# max_features: 3000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 1000  f1: 0.3357854523342813
# max_features: 3000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.3438636436325853
# max_features: 3000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.4167576585424322
# max_features: 3000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.414470443966666
# max_features: 3000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.2869852202611565
# max_features: 3000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 1  f1: 0.351159322587894
# max_features: 3000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 100  f1: 0.4172636448183317
# max_features: 3000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 1000  f1: 0.42142722638257957
# max_features: 3000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 1  f1: 0.351159322587894
# max_features: 3000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 100  f1: 0.4172636448183317
# max_features: 3000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 1000  f1: 0.42142722638257957
# max_features: 3000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 1  f1: 0.3060362142236048
# max_features: 3000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 100  f1: 0.3084437795288409
# max_features: 3000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 1000  f1: 0.3060362142236048
# max_features: 3000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 1  f1: 0.3235597512107579
# max_features: 3000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 100  f1: 0.3697550174435819
# max_features: 3000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 1000  f1: 0.3756884085595202
# max_features: 3000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 1000  f1: 0.3339932113271143
# max_features: 3000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.34313415045425644
# max_features: 3000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.39824578692178836
# max_features: 3000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.3915710008065288
# max_features: 3000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 3000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.2869852202611565
# max_features: 5000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 1  f1: 0.3637098007670214
# max_features: 5000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 100  f1: 0.4202285497821832
# max_features: 5000 n_gram: (1, 1)  kernel: linear  gamma: scale  C: 1000  f1: 0.4194965325145166
# max_features: 5000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 1  f1: 0.3637098007670214
# max_features: 5000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 100  f1: 0.4202285497821832
# max_features: 5000 n_gram: (1, 1)  kernel: linear  gamma: auto  C: 1000  f1: 0.4194965325145166
# max_features: 5000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 1  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 100  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 1)  kernel: poly  gamma: scale  C: 1000  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 1)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 1  f1: 0.31703147838044093
# max_features: 5000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 100  f1: 0.364031339031339
# max_features: 5000 n_gram: (1, 1)  kernel: rbf  gamma: scale  C: 1000  f1: 0.3671599102016146
# max_features: 5000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 1)  kernel: rbf  gamma: auto  C: 1000  f1: 0.2950052554980595
# max_features: 5000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.34534807211475194
# max_features: 5000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.40240023495166044
# max_features: 5000 n_gram: (1, 1)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.39340322008755746
# max_features: 5000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 1)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 1  f1: 0.36586187712742535
# max_features: 5000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 100  f1: 0.41765197275546856
# max_features: 5000 n_gram: (1, 2)  kernel: linear  gamma: scale  C: 1000  f1: 0.41804836331653855
# max_features: 5000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 1  f1: 0.36586187712742535
# max_features: 5000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 100  f1: 0.41765197275546856
# max_features: 5000 n_gram: (1, 2)  kernel: linear  gamma: auto  C: 1000  f1: 0.41804836331653855
# max_features: 5000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 1  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 100  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 2)  kernel: poly  gamma: scale  C: 1000  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 2)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 1  f1: 0.3235665842067127
# max_features: 5000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 100  f1: 0.3688563947947005
# max_features: 5000 n_gram: (1, 2)  kernel: rbf  gamma: scale  C: 1000  f1: 0.3712793925320949
# max_features: 5000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 2)  kernel: rbf  gamma: auto  C: 1000  f1: 0.29211360859565905
# max_features: 5000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.347905426152564
# max_features: 5000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.41643296722501305
# max_features: 5000 n_gram: (1, 2)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.4131583462280661
# max_features: 5000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 2)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 1  f1: 0.3653243466908063
# max_features: 5000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 100  f1: 0.42530145777710926
# max_features: 5000 n_gram: (1, 3)  kernel: linear  gamma: scale  C: 1000  f1: 0.43047343625134066
# max_features: 5000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 1  f1: 0.3653243466908063
# max_features: 5000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 100  f1: 0.42530145777710926
# max_features: 5000 n_gram: (1, 3)  kernel: linear  gamma: auto  C: 1000  f1: 0.43047343625134066
# max_features: 5000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 1  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 100  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 3)  kernel: poly  gamma: scale  C: 1000  f1: 0.3060362142236048
# max_features: 5000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 3)  kernel: poly  gamma: auto  C: 1000  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 1  f1: 0.3238527915037982
# max_features: 5000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 100  f1: 0.3692099118564321
# max_features: 5000 n_gram: (1, 3)  kernel: rbf  gamma: scale  C: 1000  f1: 0.3698404932749355
# max_features: 5000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 3)  kernel: rbf  gamma: auto  C: 1000  f1: 0.2974888449489728
# max_features: 5000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 1  f1: 0.34604936344904025
# max_features: 5000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 100  f1: 0.4243826438825448
# max_features: 5000 n_gram: (1, 3)  kernel: sigmoid  gamma: scale  C: 1000  f1: 0.4093094304800407
# max_features: 5000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 1  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 100  f1: 0.2867383512544803
# max_features: 5000 n_gram: (1, 3)  kernel: sigmoid  gamma: auto  C: 1000  f1: 0.2867383512544803
# 0.43047343625134066
# {'max_features': 5000, 'n_gram': (1, 3), 'kernel': 'linear', 'gamma': 'scale', 'C': 1000}

# %%
#generate classification report for best parameters

tfidf = TfidfVectorizer(max_features = chosen_parameters["max_features"], ngram_range = chosen_parameters["n_gram"])

X_train_tfidf = tfidf.fit_transform(preprocessed_train_data["text"]).toarray()
X_test_tfidf = tfidf.transform(preprocessed_test_data["text"]).toarray()
model = SVC(C = chosen_parameters["C"], kernel = chosen_parameters["kernel"], gamma = chosen_parameters["gamma"])

model.fit(X_train_tfidf, train_labels['label'])
predictions = model.predict(X_test_tfidf)
f1 = metrics.f1_score(test_labels['label'], predictions, average = 'macro')


print("F1 Score:", f1)
print(classification_report(test_labels['label'], predictions))
# Out:
# F1 Score: 0.43047343625134066
#                      precision    recall  f1-score   support
#
#       no_depression       0.81      0.84      0.82      1000
# possible_depression       0.32      0.36      0.34       250
#     true_depression       0.29      0.08      0.12        75
#
#            accuracy                           0.70      1325
#           macro avg       0.47      0.43      0.43      1325
#        weighted avg       0.69      0.70      0.69      1325

# %%
#generate confusion matrix for best parameters

conf_matrix = confusion_matrix(test_labels['label'], predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples', xticklabels = ['no_depression', 'possible_depression', 'true_depression'], yticklabels = ['no_depression', 'possible_depression', 'true_depression'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
doc = docx.Document()

doc.add_heading('Hiperparametrization', 0)

# Table data in a form of list
# data = (
#     (1, 'Geek 1'),
#     (2, 'Geek 2'),
#     (3, 'Geek 3')
# )

# Creating a table object
table = doc.add_table(rows=1, cols=6)
  # {'max_features': 5000, 'n_gram': (1, 2), 'kernel': 'linear', 'gamma': 'scale', 'C': 1000}

# Adding heading in the 1st row of the table
row = table.rows[0].cells
row[0].text = 'max_features'
row[1].text = 'n_gram'
row[2].text = 'kernel'
row[3].text = 'gamma'
row[4].text = 'C'
row[5].text = 'f1'

# Adding data from the list to the table
for elem in data:
    # Adding a row and then adding data in it.
    row = table.add_row().cells
    # Converting id to string as table can only take string input
    row[0].text = str(elem['max_features'])
    row[1].text = str(elem['n_gram'])
    row[2].text = str(elem['kernel'])
    row[3].text = str(elem['gamma'])
    row[4].text = str(elem['C'])
    row[5].text = str(round(elem['f1'],4))

# Now save the document to a location
doc.save('hiperparam_svm.docx')
