# %%
# !pip install scikit-learn
# !pip install pandas
# !pip install emoji
# !pip install num2words
# !pip install nltk
# !pip install matplotlib
# !pip install wordcloud
# !pip install python-docx
# !pip install ipynb 
# !pip install seaborn
# !pip install xgboost
# Out:
# Requirement already satisfied: scikit-learn in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pandas in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: emoji in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (2.12.1)
# Requirement already satisfied: typing-extensions>=4.7.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from emoji) (4.12.2)
# Requirement already satisfied: num2words in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (0.5.13)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from num2words) (0.6.2)
# Requirement already satisfied: nltk in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: matplotlib in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: wordcloud in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from wordcloud) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: python-docx in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-docx) (5.2.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-docx) (4.12.2)
# Requirement already satisfied: ipynb in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (0.5.1)
# Requirement already satisfied: seaborn in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: xgboost in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (2.1.0)
# Requirement already satisfied: numpy in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\tiast\onedrive\work\masters\m-1\2\bionlp\bionlp project\venv\lib\site-packages (from xgboost) (1.13.1)

# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split
import re
import emoji
from num2words import num2words
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, classification_report
nltk.download('stopwords')
nltk.download('wordnet')
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from collections import Counter
from matplotlib import colors
from wordcloud import WordCloud
from sklearn import metrics
import docx 
from ipynb.fs.full.preprocessor_class import Preprocessor
from sklearn.metrics import classification_report
import seaborn as sns
from sklearn.metrics import confusion_matrix
import xgboost as xgb
from xgboost import XGBClassifier
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tiast\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\tiast\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
train_data = pd.read_csv('data/shuffled_train_data.csv',index_col=None)
train_labels = pd.read_csv('data/shuffled_train_labels.csv',index_col=None)

test_data = pd.read_csv('data/test_data.csv',index_col=None)
test_labels = pd.read_csv('data/test_labels.csv',index_col=None)

train_data_plot = pd.read_csv('data/train_data_plot.csv',index_col=None)
test_data_plot = pd.read_csv('data/test_data_plot.csv',index_col=None)

train_data.shape
# Out:
# (2100, 1)

# %%
preprocessor = Preprocessor(set(stopwords.words('romanian')),None, None, True, True, True, True, False, True, True, True, True, False, False)

preprocessed_data = pd.DataFrame(columns=['text'])

preprocessed_train_data = pd.DataFrame(columns=['text'])
preprocessed_test_data = pd.DataFrame(columns=['text'])

preprocessed_train_data['text'] = train_data.apply(lambda row: preprocessor.preprocess(row.iloc[0]), axis = 1)
preprocessed_test_data['text'] = test_data.apply(lambda row: preprocessor.preprocess(row.iloc[0]), axis = 1)

#change the labels to numbers for xgb
train_labels['label'] = train_labels['label'].replace('no_depression', 0)
train_labels['label'] = train_labels['label'].replace('possible_depression', 1)
train_labels['label'] = train_labels['label'].replace('true_depression', 2)

test_labels['label'] = test_labels['label'].replace('no_depression', 0)
test_labels['label'] = test_labels['label'].replace('possible_depression', 1)
test_labels['label'] = test_labels['label'].replace('true_depression', 2)
# Out:
# C:\Users\tiast\AppData\Local\Temp\ipykernel_29676\3706335444.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_labels['label'] = train_labels['label'].replace('true_depression', 2)
# C:\Users\tiast\AppData\Local\Temp\ipykernel_29676\3706335444.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_labels['label'] = test_labels['label'].replace('true_depression', 2)

# %%
preprocessed_test_data['text'] = preprocessed_test_data['text'].apply(lambda x: ' '.join(map(str, x)))
preprocessed_test_data
# Out:
#                                                    text
# 0     mare durere fizica simtita clasa ten stomatolo...
# 1     petitie asf impotriva speculei asiguratorilor ...
# 2     ride sharing plecat proteste redditori masini ...
# 3     apasa trimite refugiat sprit ten salvati gold ...
# 4     politia datoria scurt depus plangere politie m...
# ...                                                 ...
# 1320  sfat buna neboie sfat facut doza vaccin contra...
# 1321  boli mintale soferii tir dn1 locuit an jumatat...
# 1322  freelancer gasesc clienti gasesc client job fr...
# 1323  furata cunostinta spune probe suficiente furat...
# 1324  merita aprofundezi js frontend devs merita inv...
#
# [1325 rows x 1 columns]

# %%
preprocessed_train_data['text'] = preprocessed_train_data['text'].apply(lambda x: ' '.join(map(str, x)))
preprocessed_train_data
# Out:
#                                                    text
# 0     rant ajuns cumparam originalul postare tip imp...
# 1     true grit secretul succesului evident ideile c...
# 2     experiente schimbat mentalitatea buna experien...
# 3     subreddit trebui numeasca r depresie casual ti...
# 4     ticalosilor entr acte unchiul scrie decat marc...
# ...                                                 ...
# 2095  mersul sala eticheta mno inceput merg sala tov...
# 2096  maine sala controla emotiile long story short ...
# 2097  stie gasesc granita italiana intors sicilia ma...
# 2098  somn permanenta stiu fac efectiv somn momentul...
# 2099  rodditori programatori oameni buni rog salvati...
#
# [2100 rows x 1 columns]

# %%
best_f1 = 0
chosen_parameters = {}
data = []

for max_features in [1000, 3000, 5000]:
  for n_gram in [(1, 1), (1, 2), (1, 3)]:
    for n_estimators in [10, 100, 1000]:
      for max_depth in [1, 10, 20]:
        for learning_rate in [0.001, 0.01, 0.1]:
            #initiate the TfidfVectorizer
            
            tfidf_vectorizer = TfidfVectorizer(max_features = max_features, ngram_range = n_gram)
            train_tfidf = tfidf_vectorizer.fit_transform(preprocessed_train_data['text']) 
            test_tfidf = tfidf_vectorizer.transform(preprocessed_test_data['text']) 
            
            model = XGBClassifier(n_estimators = 2, max_depth = 2, learning_rate = 1)
            model.fit(train_tfidf, train_labels['label'])
            
            predictions = model.predict(test_tfidf)
            f1 = metrics.f1_score(test_labels['label'], predictions, average = 'macro')
    
            print('max_features: {} n_gram: {}  n_estimators: {}  max_depth: {}  learning_rate: {}  f1: {}'.format(max_features, n_gram, n_estimators, max_depth, learning_rate, f1))
            data.append({
              "max_features": max_features,
              "n_gram": n_gram,
              "n_estimators": n_estimators,
              "max_depth": max_depth,
              "learning_rate": learning_rate,
              "f1": f1
            })
            
            if f1 > best_f1:
                best_f1 = f1
                chosen_parameters["max_features"] = max_features
                chosen_parameters["n_gram"] = n_gram      
                chosen_parameters["n_estimators"] = n_estimators
                chosen_parameters["max_depth"] = max_depth
                chosen_parameters["learning_rate"] = learning_rate

print(best_f1)
print(chosen_parameters)
# Out:
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.3146179498332608
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.31983050084922093
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.3084442334572883
# max_features: 1000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.3084442334572883
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.3085201051302746
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.3250828960755506
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.3255222645291404
# max_features: 3000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.3255222645291404
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 1)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.30691475959966336
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 2)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.32191663952099525
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 1  learning_rate: 0.1  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 10  learning_rate: 0.1  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 10  max_depth: 20  learning_rate: 0.1  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 1  learning_rate: 0.1  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 10  learning_rate: 0.1  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 100  max_depth: 20  learning_rate: 0.1  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 1  learning_rate: 0.1  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 10  learning_rate: 0.1  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.001  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.01  f1: 0.3196011232464521
# max_features: 5000 n_gram: (1, 3)  n_estimators: 1000  max_depth: 20  learning_rate: 0.1  f1: 0.3196011232464521
# 0.3255222645291404
# {'max_features': 3000, 'n_gram': (1, 3), 'n_estimators': 10, 'max_depth': 1, 'learning_rate': 0.001}

# %%
#generate classification report for best parameters

tfidf = TfidfVectorizer(max_features = chosen_parameters["max_features"], ngram_range = chosen_parameters["n_gram"])

X_train_tfidf = tfidf.fit_transform(preprocessed_train_data["text"]).toarray()
X_test_tfidf = tfidf.transform(preprocessed_test_data["text"]).toarray()
model = XGBClassifier(n_estimators = chosen_parameters["n_estimators"], max_depth = chosen_parameters["max_depth"], learning_rate = chosen_parameters["learning_rate"])

model.fit(X_train_tfidf, train_labels['label'])
predictions = model.predict(X_test_tfidf)
f1 = metrics.f1_score(test_labels['label'], predictions, average = 'macro')

print("F1 Score:", f1)
print(classification_report(test_labels['label'], predictions))
# Out:
# {'max_features': 3000, 'n_gram': (1, 3), 'n_estimators': 10, 'max_depth': 1, 'learning_rate': 0.001}
# F1 Score: 0.2867383512544803
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86      1000
#            1       0.00      0.00      0.00       250
#            2       0.00      0.00      0.00        75
#
#     accuracy                           0.75      1325
#    macro avg       0.25      0.33      0.29      1325
# weighted avg       0.57      0.75      0.65      1325
# C:\Users\tiast\OneDrive\work\masters\m-1\2\BioNLP\BioNLP Project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\tiast\OneDrive\work\masters\m-1\2\BioNLP\BioNLP Project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\tiast\OneDrive\work\masters\m-1\2\BioNLP\BioNLP Project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#generate confusion matrix for best parameters

conf_matrix = confusion_matrix(test_labels['label'], predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples', xticklabels = ['possible_depression', 'true_depression', 'no_depression'], yticklabels = ['possible_depression', 'true_depression', 'no_depression'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
doc = docx.Document()

doc.add_heading('Hiperparametrization', 0)

# Table data in a form of list
# data = (
#     (1, 'Geek 1'),
#     (2, 'Geek 2'),
#     (3, 'Geek 3')
# )

# Creating a table object
table = doc.add_table(rows=1, cols=6)
best_f1 = 0
  # 'max_features': 3000, 'n_gram': (1, 3), 'n_estimators': 10, 'max_depth': 1, 'learning_rate': 0.001}

# Adding heading in the 1st row of the table
row = table.rows[0].cells
row[0].text = 'max_features'
row[1].text = 'n_gram'
row[2].text = 'n_estimators'
row[3].text = 'max_depth'
row[4].text = 'learning_rate'
row[5].text = 'f1'

# Adding data from the list to the table
for elem in data:
    # Adding a row and then adding data in it.
    row = table.add_row().cells
    # Converting id to string as table can only take string input
    row[0].text = str(elem['max_features'])
    row[1].text = str(elem['n_gram'])
    row[2].text = str(elem['n_estimators'])
    row[3].text = str(elem['max_depth'])
    row[4].text = str(elem['learning_rate'])
    row[5].text = str(round(elem['f1'],4))

# Now save the document to a location
doc.save('hiperparam_xgb.docx')
